# %% [markdown]
# **Project:** Data Minining Project for  X company

# %% [markdown]
# The CRISP-DM Framework
#
#
# The CRISP-DM methodology provides a structured approach to planning a data mining project. It is a robust and well-proven methodology.
# * Business understanding (BU): Determine Business Objectives, Assess Situation, Determine Data Mining Goals, Produce Project Plan
#
# * Data understanding (DU): Collect Initial Data, Describe Data, Explore Data, Verify Data Quality
#
# * Data preparation (DP): Select Data, Clean Data, Construct Data, Integrate Data
#
# * Modeling (M): Select modeling technique, Generate Test Design, Build Model, Assess Model
# *  Evaluation (E): Evaluate Results, Review Process, Determine Next Steps
# *  Deployment (D): Plan Deployment, Plan Monitoring and Maintenance, Produce Final Report, Review Project
#
#
# References:
#
# [What is the CRISP-DM methodology?](https://www.sv-europe.com/crisp-dm-methodology/)
#
# [Introduction to CRISP DM Framework for Data Science and Machine Learning](https://www.linkedin.com/pulse/chapter-1-introduction-crisp-dm-framework-data-science-anshul-roy/)

# %% [markdown]
# **Data Set**
# ### The data is for company X which is trying to control attrition.
# ### There are two sets of data: "Existing employees" and "Employees who have left". The following attributes are available for every employee.
#
#
# *   Satisfaction Level
#
# *   Last evaluation
#
# *   Number of projects
#
# *   Average monthly hours
#
# *   Time spent at the company
# *   Whether they have had a work accident
#
#
# *  Whether they have had a promotion in the last 5 years
#
#
# *   Departments (column sales)
#
#
# *   Salary
#
#
# *  Whether the employee has left

# %% [markdown]
# **Your Role**
#
#
# *   As data science team member X company asked you to answer this two questions.
# *  What type of employees is leaving?
#
# *   Determine which employees are prone to leave next.

# %% [markdown]
# Business Understanding
#
# ---
#
# This step mostly focuses on understanding the Business in all the different aspects. It follows the below different steps.
#
#
#
#
# * Identify the goal and frame the business problem.
# * Prepare Analytical Goal i.e. what type of performance metric and loss function to use
# * Gather information on resource, constraints, assumptions, risks etc
# * Gather information on resource, constraints, assumptions, risks etc
# *   Prepare Work Flow Chart

# %% [markdown]
# ### Write the main objectives of this project in your words?
# minimum of 100 characters

# %%
main_objectives ='''
The main objectives for the project are 
  1. Keep employees from leaving company X
  2. Increase the length of time employees work at company X
  3. Identify essential employee retention factors
'''

# %%
assert len(main_objectives) > 100 
### BEGIN HIDDEN TESTS
assert len(main_objectives) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### Outline the different data analysis steps you will follow to carry out the project

# %%
dm_outline = '''
Here are the steps I will follow in this project:
  1. Business problem understanding
  2. Extract and understand the datasets 
  3. Manage missing values and outliers
  4. Transform the data, if necessary
  5. Perform feature engineering tasks
  6. Split the data set into training, validation, and testing sets
  7. Build classifier models
  8. Evaluate models performance and choose the best model
  9. Present the result to stakeholders to make informed decisions
'''

# %%
assert len(dm_outline) > 100 
### BEGIN HIDDEN TESTS
assert len(dm_outline) > 70 
### END HIDDEN TESTS

# %% [markdown]
# ### What metrics will you use to measure the performance of your data analysis model?
# Write the equations of the metrics here

# %% [markdown]
# e.g. Precision = $\frac{TP}{(TP + FP)}$

# %% [markdown]
# Why do you choose these metrics? minimum of 100 characters

# %%
why_metrics = '''
If the model were to give a huge percentage of false positives, 
meaning for example predict most employees will stay in the company, 
and they end up leaving or vice versa, the model would not be of any value. 

Choosing this metric helps me minimize the gap between the number of 
employees predicted to leave company X to employees leaving company X.
'''

# %%
assert len(why_metrics) > 100 
### BEGIN HIDDEN TESTS
assert len(why_metrics) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ### How would you know if your data analysis work is a success or not?
# minimum of 100 characters

# %%
how_success = '''
  My work is success if the model helped company x reduce employees from leaving the company. 
  And also show the essential employee retention factors and how they can improve
'''

# %%
assert len(how_success) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# ## What kind of challenges do you expect in your analysis?
# List at least 3 challenges

# %%
challenge_text = '''
The main challenges that I expect in my data analysis process are:
  1. Quantity of data
  2. Missing values that are difficult to infer from the rest of the data
  3. Undiscovered but relevant features that are hard to engineer
  4. Model overfitting
'''

# %%
assert len(challenge_text) > 100 
### BEGIN HIDDEN TESTS
assert len(how_success) > 80 
### END HIDDEN TESTS

# %% [markdown]
# <h2>Using the processed twitter data from yesterday's challenge</h2>.
#
#
# - Form a new data frame (named `cleanTweet`), containing columns $\textbf{clean-text}$ and $\textbf{polarity}$.
#
# - Write a function `text_category` that takes a value `p` and returns, depending on the value of p, a string `'positive'`, `'negative'` or `'neutral'`.
#
# - Apply this function (`text_category`) on the $\textbf{polarity}$ column of `cleanTweet` in 1 above to form a new column called $\textbf{score}$ in `cleanTweet`.
#
# - Visualize The $\textbf{score}$ column using piechart and barchart
#
# <h5>Now we want to build a classification model on the clean tweet following the steps below:</h5>
#
# * Remove rows from `cleanTweet` where $\textbf{polarity}$ $= 0$ (i.e where $\textbf{score}$ = Neutral) and reset the frame index.
# * Construct a column $\textbf{scoremap}$ Use the mapping {'positive':1, 'negative':0} on the $\textbf{score}$ column
# * Create feature and target variables `(X,y)` from $\textbf{clean-text}$ and $\textbf{scoremap}$ columns respectively.
# * Use `train_test_split` function to construct `(X_train, y_train)` and `(X_test, y_test)` from `(X,y)`
#
# * Build an `SGDClassifier` model from the vectorize train text data. Use `CountVectorizer()` with a $\textit{trigram}$ parameter.
#
# * Evaluate your model on the test data.

# %% [markdown]
# ## Extract clean tweets with polarity.

# %% [markdown]
# ### Form a new data frame (named `cleanTweet`), containing columns $\textbf{clean-text}$ and $\textbf{polarity}$

# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings('ignore')

# %%
cleanTweet = pd.read_csv("../processed_tweet_data.csv", usecols=['original_text', 'polarity', 'lang'])
cleanTweet = cleanTweet[cleanTweet['lang'] == 'en']
cleanTweet.drop(['lang'], axis=1, inplace=True)
cleanTweet
# Out:
#                                           original_text  polarity
# 0     🚨Africa is "in the midst of a full-blown third...  0.166667
# 1     Dr Moeti is head of WHO in Africa, and one of ...  0.133333
# 2     Thank you @research2note for creating this ama...  0.316667
# 3     Former Pfizer VP and Virologist, Dr. Michael Y...  0.086111
# 4     I think it’s important that we don’t sell COVA...  0.280000
# ...                                                 ...       ...
# 6527  RT @Givenkazeni: Zweli please just release the...  0.000000
# 6528  Former Pfizer VP and Virologist, Dr. Michael Y...  0.086111
# 6529  @Jenfeds73 @DcrInYYC Respectfully, veterinaria...  0.281250
# 6530  "Africa needs millions more doses here &amp; n...  0.125000
# 6531  RT @shawajason: Liars. You tried to load off y...  0.000000
#
# [6532 rows x 2 columns]

# %%
def clean_tweet(tweet):
    clean_tweet = re.sub("[^a-zA-Z]",  " ",  tweet)
    return clean_tweet

# %%
cleanTweet["clean-text"] = cleanTweet.original_text.apply(clean_tweet)
cleanTweet.drop(['original_text'], axis=1, inplace=True)
cleanTweet
# Out:
#       polarity                                         clean-text
# 0     0.166667   Africa is  in the midst of a full blown third...
# 1     0.133333  Dr Moeti is head of WHO in Africa  and one of ...
# 2     0.316667  Thank you  research note for creating this ama...
# 3     0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...
# 4     0.280000  I think it s important that we don t sell COVA...
# ...        ...                                                ...
# 6527  0.000000  RT  Givenkazeni  Zweli please just release the...
# 6528  0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...
# 6529  0.281250   Jenfeds    DcrInYYC Respectfully  veterinaria...
# 6530  0.125000   Africa needs millions more doses here  amp  n...
# 6531  0.000000  RT  shawajason  Liars  You tried to load off y...
#
# [6532 rows x 2 columns]

# %%
print("duplicate count: {}".format(cleanTweet.isnull().sum().sum()))
# Out:
# duplicate count: 0

# %% [markdown]
# ### Write a function `text_category` that takes a value `p` and returns, depending on the value of p, a string `'positive'`, `'negative'` or `'neutral'`.

# %%
def text_category(p):
  if p > 0:
    return "positive"
  elif p < 0:
    return "negative"
  else:
    return "neutral"

# %% [markdown]
# ### Apply this function (`text_category`) on the $\textbf{polarity}$ column of `cleanTweet` in 1 above to form a new column called $\textbf{score}$ in `cleanTweet`.

# %%
cleanTweet["score"] = cleanTweet["polarity"].apply(text_category)
cleanTweet
# Out:
#       polarity                                         clean-text     score
# 0     0.166667   Africa is  in the midst of a full blown third...  positive
# 1     0.133333  Dr Moeti is head of WHO in Africa  and one of ...  positive
# 2     0.316667  Thank you  research note for creating this ama...  positive
# 3     0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 4     0.280000  I think it s important that we don t sell COVA...  positive
# ...        ...                                                ...       ...
# 6527  0.000000  RT  Givenkazeni  Zweli please just release the...   neutral
# 6528  0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 6529  0.281250   Jenfeds    DcrInYYC Respectfully  veterinaria...  positive
# 6530  0.125000   Africa needs millions more doses here  amp  n...  positive
# 6531  0.000000  RT  shawajason  Liars  You tried to load off y...   neutral
#
# [6532 rows x 3 columns]

# %% [markdown]
# ### Visualize The $\textbf{score}$ column using piechart and barchart

# %%
category = cleanTweet.groupby(['score']).size()
category
# Out:
# score
# negative    1277
# neutral     1829
# positive    3426
# dtype: int64

# %%
category.plot(kind='pie', y='score')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
category.plot(kind='bar', y='score')
# Out:
# <AxesSubplot:xlabel='score'>

# %% [markdown]
# ## build a classification model on the clean tweet.

# %% [markdown]
# ### Remove rows from `cleanTweet` where $\textbf{polarity}$ $= 0$ (i.e where $\textbf{score}$ = Neutral) and reset the frame index.

# %%
cleanTweet = cleanTweet[cleanTweet['score'] != 'neutral']
cleanTweet
# Out:
#       polarity                                         clean-text     score
# 0     0.166667   Africa is  in the midst of a full blown third...  positive
# 1     0.133333  Dr Moeti is head of WHO in Africa  and one of ...  positive
# 2     0.316667  Thank you  research note for creating this ama...  positive
# 3     0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 4     0.280000  I think it s important that we don t sell COVA...  positive
# ...        ...                                                ...       ...
# 6524 -0.050000  Covid   vaccines reach the remotest places of ...  negative
# 6526  0.500000  Although there is not yet a vaccine for kids t...  positive
# 6528  0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 6529  0.281250   Jenfeds    DcrInYYC Respectfully  veterinaria...  positive
# 6530  0.125000   Africa needs millions more doses here  amp  n...  positive
#
# [4703 rows x 3 columns]

# %% [markdown]
# ### Construct a column $\textbf{scoremap}$ Use the mapping {'positive':1, 'negative':0} on the $\textbf{score}$ column

# %%
cleanTweet['scoremap'] = cleanTweet["score"].map( lambda score: 1 if score == "positive" else 0)
cleanTweet
# Out:
#       polarity                                         clean-text     score  \
# 0     0.166667   Africa is  in the midst of a full blown third...  positive
# 1     0.133333  Dr Moeti is head of WHO in Africa  and one of ...  positive
# 2     0.316667  Thank you  research note for creating this ama...  positive
# 3     0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 4     0.280000  I think it s important that we don t sell COVA...  positive
# ...        ...                                                ...       ...
# 6524 -0.050000  Covid   vaccines reach the remotest places of ...  negative
# 6526  0.500000  Although there is not yet a vaccine for kids t...  positive
# 6528  0.086111  Former Pfizer VP and Virologist  Dr  Michael Y...  positive
# 6529  0.281250   Jenfeds    DcrInYYC Respectfully  veterinaria...  positive
# 6530  0.125000   Africa needs millions more doses here  amp  n...  positive
#
#       scoremap
# 0            1
# 1            1
# ...

# %% [markdown]
# ### Create feature and target variables `(X,y)` from $\textbf{clean-text}$ and $\textbf{scoremap}$ columns respectively.

# %%
(X, y) = cleanTweet['clean-text'], cleanTweet['scoremap']

# %% [markdown]
# ### Use `train_test_split` function to construct `(X_train, y_train)` and `(X_test, y_test)` from `(X,y)`

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Build an `SGDClassifier` model from the vectorize train text data. Use `CountVectorizer()` with a $\textit{trigram}$ parameter and Evaluate your model on the test data.

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from joblib import dump, load # used for saving and loading sklearn objects
from scipy.sparse import save_npz, load_npz # used for saving and loading sparse matrices
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split

# %%
trigram_vectorizer = CountVectorizer(ngram_range=(3, 3))
trigram_vectorizer.fit_transform(X)
# Out:
# <4703x26289 sparse matrix of type '<class 'numpy.int64'>'
# 	with 149377 stored elements in Compressed Sparse Row format>

# %%
trigram_vectorizer = CountVectorizer(ngram_range=(1, 3))
trigram_vectorizer.fit_transform(X.values)

X_trigram = trigram_vectorizer.transform(X)


def train_and_show_scores(X, y, title: str) -> None:
    X_train, X_valid, y_train, y_valid = train_test_split(
        X, y, train_size=0.75, stratify=y
    )

    clf = SGDClassifier()
    clf.fit(X_train, y_train)
    train_score = clf.score(X_train, y_train)
    valid_score = clf.score(X_valid, y_valid)
    print(f'{title}\nTrain score: {round(train_score, 2)} ; Validation score: {round(valid_score, 2)}\n')

# %%
train_and_show_scores(X_trigram, cleanTweet['scoremap'], title="sentiment")
# Out:
# sentiment
# Train score: 1.0 ; Validation score: 0.96
